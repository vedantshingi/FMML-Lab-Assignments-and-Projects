# %%
from PIL import Image
filepath = "/content/drive/MyDrive/tree-736885__480.jpg"
img = Image.open(filepath)
size = img.size
print(size)
# Out:
# (771, 480)

# %%
num = int(input("enter a number to be reversed"))
num2 = int(input("enter other number"))
reversed_num = 0

while num != 0:
    digit = num % 10
    reversed_num = reversed_num * 10 + digit
    num //= 10
sum = reversed_num + num2
print(sum)
# Out:
# enter a number to be reversed45
# enter other number34
# 88
